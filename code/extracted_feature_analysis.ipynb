# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler


df = pd.read_csv('Dataset/dataset.csv')

print(df.head())
# Out:
#           X         Y         Z     Mixed  ClassLabel
# 0  0.125022  0.094986  0.001297  0.157018           1
# 1  0.150710  0.083282 -0.023514  0.173788           1
# 2  0.102941  0.111084  0.010075  0.151782           1
# 3  0.038450  0.049911  0.007511  0.063451           1
# 4 -0.029148 -0.105423  0.017124  0.110711           1

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                    X         Y         Z     Mixed  ClassLabel
# X           1.000000  0.007068  0.000636  0.012091    0.002288
# Y           0.007068  1.000000  0.000528 -0.010159    0.006812
# Z           0.000636  0.000528  1.000000  0.010151    0.020246
# Mixed       0.012091 -0.010159  0.010151  1.000000    0.120128
# ClassLabel  0.002288  0.006812  0.020246  0.120128    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt

# Iterate over each column in the DataFrame
for column in df.columns:
    plt.figure(figsize=(8, 6))
    # Create a box plot for the current column
    df.boxplot(column=column)
    plt.title('Box plot for ' + column)
    plt.ylabel('Values')
    plt.show()
