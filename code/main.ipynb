# %%
import pandas as pd

df = pd.read_csv('Dataset.csv')

print(df.head())
# Out:
#      aX     aY    aZ    gX    gY    gZ    mX  mY  mZ  Result
# 0 -2544  14340 -6864  3840  -335 -1518 -1760  -1  -1       1
# 1 -2380  14188 -5644  3888  1635 -9604 -2419  -1  -1       1
# 2  -524  14480 -7148  3888 -1663 -1491   311  -1  -1       1
# 3  -528  15052 -6672  3904   461 -4012 -1424  -1  -1       1
# 4 -2808  14040 -5936  3904   595  -339    13  -1  -1       1

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#               aX        aY        aZ        gX        gY        gZ        mX  \
# aX      1.000000  0.348812  0.254270 -0.014819 -0.053465  0.010518  0.016108
# aY      0.348812  1.000000  0.897829 -0.447115  0.218318  0.027642 -0.029024
# aZ      0.254270  0.897829  1.000000 -0.489829  0.239983  0.044370 -0.036868
# gX     -0.014819 -0.447115 -0.489829  1.000000 -0.030110  0.009800  0.006617
# gY     -0.053465  0.218318  0.239983 -0.030110  1.000000  0.040939 -0.372281
# gZ      0.010518  0.027642  0.044370  0.009800  0.040939  1.000000  0.785830
# mX      0.016108 -0.029024 -0.036868  0.006617 -0.372281  0.785830  1.000000
# mY           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# mZ           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Result  0.547677  0.149913  0.148429  0.212494 -0.012199  0.001477  0.002648
#
#         mY  mZ    Result
# aX     NaN NaN  0.547677
# aY     NaN NaN  0.149913
# aZ     NaN NaN  0.148429
# gX     NaN NaN  0.212494
# gY     NaN NaN -0.012199
# gZ     NaN NaN  0.001477
# mX     NaN NaN  0.002648
# mY     NaN NaN       NaN
# mZ     NaN NaN       NaN
# Result NaN NaN  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt

# Iterate over each column in the DataFrame
for column in df.columns:
    plt.figure(figsize=(8, 6))
    # Create a box plot for the current column
    df.boxplot(column=column)
    plt.title('Box plot for ' + column)
    plt.ylabel('Values')
    plt.show()
