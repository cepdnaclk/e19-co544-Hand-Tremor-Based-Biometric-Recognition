# %% [markdown]
# ## SVM

# %% [markdown]
# ### RBF kernel

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
df = pd.read_csv('Dataset/NoInfValues.csv')
df.head()
# Out:
#        mean   std_dev    energy   entropy  num_peaks  lbp_0  lbp_1  ClassLabel
# 0  0.094581  0.058153  0.049309  1.097330        0.0      2      3           1
# 1  0.093970  0.051851  0.046076  1.178120        1.0      0      3           1
# 2  0.039831  0.020652  0.008052  1.217346        1.0      0      3           1
# 3  0.077550  0.050505  0.034259  1.115788        1.0      0      3           1
# 4  0.093627  0.051805  0.045799  1.178472        1.0      0      3           1

# %%
df.describe()
# Out:
#              mean     std_dev         energy     entropy   num_peaks  \
# count  578.000000  578.000000     578.000000  578.000000  578.000000
# mean     0.547162    0.563072     932.778758    1.177060    0.619377
# std      9.832225   11.675131   22421.517225    0.117442    0.485961
# min      0.006453    0.002335       0.000188    0.587278    0.000000
# 25%      0.053044    0.030800       0.015532    1.109699    0.000000
# 50%      0.113274    0.061033       0.068240    1.192146    1.000000
# 75%      0.185966    0.103410       0.189697    1.268512    1.000000
# max    236.505877  280.762302  539050.000276    1.352549    1.000000
#
#             lbp_0       lbp_1  ClassLabel
# count  578.000000  578.000000  578.000000
# mean     0.859862    2.572664    3.093426
# std      1.177231    0.823662    1.267481
# min      0.000000    0.000000    1.000000
# 25%      0.000000    3.000000    2.000000
# 50%      0.000000    3.000000    3.000000
# 75%      2.000000    3.000000    4.000000
# max      3.000000    3.000000    5.000000

# %%
# Separate features and target
x = df.iloc[:, :-1]  # Features
y = df.iloc[:, -1]   # Target

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
# Train the Model
classifier_rbf = SVC(kernel = "rbf", random_state = 42)
classifier_rbf.fit(x_train,y_train)
# Out:
# SVC(random_state=42)

# %%
# Predict
y_pred = classifier_rbf.predict(x_test)

# %%
# Evauavte the model
classifier_rbf.score(x, y)
# Out:
# 0.23529411764705882

# %%
cm_rbf = confusion_matrix(y_test, y_pred)
cm_rbf
# Out:
# array([[ 0,  0, 17,  0,  0],
#        [ 0,  0, 55,  0,  0],
#        [ 0,  0, 35,  0,  0],
#        [ 0,  0, 40,  0,  0],
#        [ 0,  0, 27,  0,  0]])

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.20114942528735633

# %%
cr_rbf = classification_report(y_test, y_pred)
print(cr_rbf)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        17
#            2       0.00      0.00      0.00        55
#            3       0.20      1.00      0.33        35
#            4       0.00      0.00      0.00        40
#            5       0.00      0.00      0.00        27
#
#     accuracy                           0.20       174
#    macro avg       0.04      0.20      0.07       174
# weighted avg       0.04      0.20      0.07       174
# /home/dasun/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/dasun/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/dasun/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Tune Hyper Parameters

# %%
# Standardize the features
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf']
}

# Initialize the GridSearchCV object
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf']},
#              verbose=2)

# %%
grid.best_estimator_
# Out:
# SVC(C=100, gamma=1)

# %%
# Use the best estimator to make predictions
y_pred = grid.best_estimator_.predict(x_test)

# %%
classifier_rbf.score(x, y)
# Out:
# 0.23529411764705882

# %%
# Evaluate the model
accuracy_score(y_test, y_pred)
# Out:
# 0.40804597701149425

# %%
confusion_mat = confusion_matrix(y_test, y_pred)
confusion_mat
# Out:
# array([[ 1,  5,  8,  2,  1],
#        [ 0, 43,  0,  5,  7],
#        [ 0,  9, 10, 10,  6],
#        [ 0, 13,  6, 16,  5],
#        [ 1, 10,  8,  7,  1]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.06      0.11        17
#            2       0.54      0.78      0.64        55
#            3       0.31      0.29      0.30        35
#            4       0.40      0.40      0.40        40
#            5       0.05      0.04      0.04        27
#
#     accuracy                           0.41       174
#    macro avg       0.36      0.31      0.30       174
# weighted avg       0.38      0.41      0.37       174

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'C': [100, 150, 200],
    'gamma': [1, 1.1, 0.9],
    'kernel': ['rbf']
}

# Initialize the GridSearchCV object
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.0s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [100, 150, 200], 'gamma': [1, 1.1, 0.9],
#                          'kernel': ['rbf']},
#              verbose=2)

# %%
grid.best_estimator_
# Out:
# SVC(C=200, gamma=0.9)

# %%
# Use the best estimator to make predictions
y_pred = grid.best_estimator_.predict(x_test)

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.33      0.06      0.10        17
#            2       0.63      0.76      0.69        55
#            3       0.32      0.34      0.33        35
#            4       0.44      0.50      0.47        40
#            5       0.14      0.11      0.12        27
#
#     accuracy                           0.45       174
#    macro avg       0.37      0.36      0.34       174
# weighted avg       0.42      0.45      0.42       174

# %% [markdown]
# ### dataset.csv

# %%
df2 = pd.read_csv('Dataset/dataset.csv')
df2.head()
# Out:
#           X         Y         Z     Mixed  ClassLabel
# 0  0.125022  0.094986  0.001297  0.157018           1
# 1  0.150710  0.083282 -0.023514  0.173788           1
# 2  0.102941  0.111084  0.010075  0.151782           1
# 3  0.038450  0.049911  0.007511  0.063451           1
# 4 -0.029148 -0.105423  0.017124  0.110711           1

# %%
df2.describe()
# Out:
#                  X            Y             Z        Mixed   ClassLabel
# count  5035.000000  5035.000000  5.035000e+03  5035.000000  5035.000000
# mean      0.521365     4.697800 -2.947934e+02     0.244225     3.002781
# std     318.671126   233.800423  2.026480e+04     0.192936     1.409145
# min   -9720.000000 -8850.000000 -1.437653e+06     0.001157     1.000000
# 25%      -0.069452    -0.100594 -6.593132e-02     0.094546     2.000000
# 50%      -0.001627     0.007843 -3.307343e-03     0.196968     3.000000
# 75%       0.071264     0.124863  5.086803e-02     0.343273     4.000000
# max    8960.000000  7630.000000  9.000000e+03     0.995577     5.000000

# %%
df2.isnull().sum()
# Out:
# X             0
# Y             0
# Z             0
# Mixed         0
# ClassLabel    0
# dtype: int64

# %%
x = df2.iloc[:, :-1]  # Features
x.head()
# Out:
#           X         Y         Z     Mixed
# 0  0.125022  0.094986  0.001297  0.157018
# 1  0.150710  0.083282 -0.023514  0.173788
# 2  0.102941  0.111084  0.010075  0.151782
# 3  0.038450  0.049911  0.007511  0.063451
# 4 -0.029148 -0.105423  0.017124  0.110711

# %%
y = df2.iloc[:, -1]   # Target
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: ClassLabel, dtype: int64

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
SD = StandardScaler()
x_train = SD.fit_transform(x_train)
x_test = SD.fit_transform(x_test)

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'C': [100, 150, 200],
    'gamma': [1, 1.1, 0.9],
    'kernel': ['rbf']
}

# Initialize the GridSearchCV object
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=100, gamma=1.1, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.9, kernel=rbf; total time=   0.4s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=150, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.6s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.6s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.7s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.6s
# [CV] END .......................C=150, gamma=1.1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.5s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.5s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.5s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.5s
# [CV] END .......................C=150, gamma=0.9, kernel=rbf; total time=   0.5s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.7s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.6s
# [CV] END .........................C=200, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.8s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.7s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.8s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.8s
# [CV] END .......................C=200, gamma=1.1, kernel=rbf; total time=   0.7s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.6s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.6s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.7s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.6s
# [CV] END .......................C=200, gamma=0.9, kernel=rbf; total time=   0.6s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [100, 150, 200], 'gamma': [1, 1.1, 0.9],
#                          'kernel': ['rbf']},
#              verbose=2)

# %%
grid.best_estimator_
# Out:
# SVC(C=150, gamma=1.1)

# %%
# Use the best estimator to make predictions
y_pred = grid.best_estimator_.predict(x_test)

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.01      0.02       310
#            2       0.72      0.81      0.77       319
#            3       0.34      0.69      0.45       282
#            4       0.31      0.58      0.41       303
#            5       0.00      0.00      0.00       297
#
#     accuracy                           0.42      1511
#    macro avg       0.37      0.42      0.33      1511
# weighted avg       0.38      0.42      0.33      1511

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf']
}

# Initialize the GridSearchCV object
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.3s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.3s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.2s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf']},
#              verbose=2)

# %%
grid.best_estimator_
# Out:
# SVC(C=100, gamma=0.1)

# %%
# Use the best estimator to make predictions
y_pred = grid.best_estimator_.predict(x_test)

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.18      0.02      0.03       310
#            2       0.72      0.84      0.77       319
#            3       0.34      0.63      0.44       282
#            4       0.31      0.58      0.40       303
#            5       0.00      0.00      0.00       297
#
#     accuracy                           0.41      1511
#    macro avg       0.31      0.41      0.33      1511
# weighted avg       0.31      0.41      0.33      1511

# %%
# Train the Model
classifier_linear = SVC(kernel = "linear", random_state = 42)
classifier_linear.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
x_test.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 x_test.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
# Use the best estimator to make predictions
y_pred = grid.best_estimator_.predict(x_test)

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)

# %% [markdown]
# ## combined_metrics.csv data set

# %%
df = pd.read_csv('combined_metrics.csv')
df.head()
# Out:
#      Mean_X  Std Dev_X  Energy_X  Entropy_X  Peaks_X    Mean_Y  Std Dev_Y  \
# 0  0.025967   0.149649  2.284523 -10.269194       17  0.019115   0.236742
# 1  0.024132   0.149547  2.272307 -10.310649       16  0.020332   0.237447
# 2  0.021001   0.150147  2.275984  -9.992131       16  0.021384   0.237961
# 3  0.019992   0.149930  2.265391 -10.067565       16  0.025724   0.243507
# 4  0.019370   0.149982  2.264473 -10.036759       17  0.029207   0.246331
#
#    Energy_Y  Entropy_Y  Peaks_Y  Mean_Mixed  Std Dev_Mixed  Energy_Mixed  \
# 0  5.585155  -1.251265       20    0.268438       0.139471      9.131639
# 1  5.623074  -1.204877       20    0.269707       0.139023      9.187616
# 2  5.651662  -1.171929       20    0.270788       0.138690      9.236838
# 3  5.936428  -0.909256       20    0.274968       0.141341      9.538472
# 4  6.092519  -0.772432       21    0.278490       0.140402      9.707206
#
#    Entropy_Mixed  Peaks_Mixed  category
# 0     -18.530758           27         1
# 1     -18.425003           26         1
# 2     -18.255960           27         1
# 3     -17.979045           27         1
# 4     -18.063853           27         1

# %%
df.describe()
# Out:
#             Mean_X    Std Dev_X     Energy_X     Entropy_X      Peaks_X  \
# count  4388.000000  4383.000000  4388.000000   4388.000000  4388.000000
# mean      0.004006     0.089387     1.072148   -158.810492    15.977666
# std       0.024133     0.056847     1.001885    764.138718     4.292311
# min      -0.191591     0.002174     0.000001 -34694.374782     0.000000
# 25%      -0.002825     0.024238     0.058274   -300.552498    14.000000
# 50%       0.000338     0.103842     1.025896    -27.489962    17.000000
# 75%       0.011288     0.139175     1.921716    -14.100193    19.000000
# max       0.258800     0.238033     3.431192     -6.108219    24.000000
#
#             Mean_Y    Std Dev_Y     Energy_Y      Entropy_Y      Peaks_Y  \
# count  4388.000000  4383.000000  4388.000000    4388.000000  4388.000000
# mean      0.009437     0.135307     2.314744    -252.328564    19.127165
# std       0.024470     0.076748     2.099678    9279.406230     5.218609
# min      -0.142838     0.000227     0.000059 -434709.340039     0.000000
# 25%      -0.004412     0.051360     0.261709    -102.262692    17.000000
# 50%       0.003829     0.142736     1.926557     -13.497040    20.000000
# 75%       0.019464     0.206085     4.195303      -3.364960    23.000000
# max       0.257938     0.316833     7.932150       0.710296    30.000000
#
#         Mean_Mixed  Std Dev_Mixed  Energy_Mixed  Entropy_Mixed  Peaks_Mixed  \
# count  4388.000000    4383.000000   4388.000000    4388.000000  4388.000000
# mean      0.160095       0.080044      4.065248    -314.594699    27.043072
# std       0.096438       0.046162      3.680242    7930.806030     5.782330
# min       0.008352       0.000261      0.000073 -371539.304425     0.000000
# 25%       0.051069       0.028717      0.341078    -285.032911    27.000000
# 50%       0.179642       0.085308      3.665701     -47.255963    28.000000
# 75%       0.252299       0.124242      7.467996     -20.995007    30.000000
# max       0.358251       0.170074     12.525864     -12.686242    35.000000
#
#           category
# count  4388.000000
# mean      2.997949
# std       1.412841
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000

# %%
df.isnull().sum()
# Out:
# Mean_X           0
# Std Dev_X        5
# Energy_X         0
# Entropy_X        0
# Peaks_X          0
# Mean_Y           0
# Std Dev_Y        5
# Energy_Y         0
# Entropy_Y        0
# Peaks_Y          0
# Mean_Mixed       0
# Std Dev_Mixed    5
# Energy_Mixed     0
# Entropy_Mixed    0
# Peaks_Mixed      0
# category         0
# dtype: int64

# %%
# Separate features and target
x = df.iloc[:, :-1]  # Features
y = df.iloc[:, -1]   # Target

# %%
# Handle infinity and large values by replacing them with NaN
x.replace([np.inf, -np.inf], np.nan, inplace=True)
x.fillna(x.mean(), inplace=True)

# %%
# Standardize the features
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.3, random_state = 42)

# %%
# Train the Model
classifier_rbf = SVC(kernel = "rbf", random_state = 42)
classifier_rbf.fit(x_train,y_train)
# Out:
# SVC(random_state=42)

# %%
# Predict
y_pred = classifier_rbf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7691723614274867

# %%
# Train the Model
classifier_lnr = SVC(kernel = "linear", random_state = 42)
classifier_lnr.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Predict
y_pred = classifier_rbf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7691723614274867

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['rbf', 'linear']
}

# Initialize the GridSearchCV object
grid = GridSearchCV(SVC(gamma = 'auto'), param_grid, refit=True, verbose=2, cv  = 5)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.5s
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.3s
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.3s
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.3s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.2s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.2s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.3s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.2s
# [CV] END .................................C=1, kernel=linear; total time=   0.2s
# [CV] END .................................C=1, kernel=linear; total time=   0.2s
# [CV] END .................................C=1, kernel=linear; total time=   0.3s
# [CV] END .................................C=1, kernel=linear; total time=   0.2s
# [CV] END .................................C=1, kernel=linear; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ................................C=10, kernel=linear; total time=   0.1s
# [CV] END ................................C=10, kernel=linear; total time=   0.3s
# [CV] END ................................C=10, kernel=linear; total time=   0.3s
# [CV] END ................................C=10, kernel=linear; total time=   0.3s
# [CV] END ................................C=10, kernel=linear; total time=   0.2s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.3s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.2s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.2s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.2s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.2s
# [CV] END ...............................C=100, kernel=linear; total time=   0.4s
# [CV] END ...............................C=100, kernel=linear; total time=   0.5s
# [CV] END ...............................C=100, kernel=linear; total time=   0.4s
# [CV] END ...............................C=100, kernel=linear; total time=   0.3s
# [CV] END ...............................C=100, kernel=linear; total time=   0.3s
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [0.1, 1, 10, 100], 'kernel': ['rbf', 'linear']},
#              verbose=2)

# %%
grid.best_estimator_
# Out:
# SVC(C=10, gamma='auto')

# %%
result = pd.DataFrame(grid.cv_results_)
result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.217731      0.076991         0.138790        0.017388     0.1
# 1       0.107149      0.010327         0.047482        0.012608     0.1
# 2       0.144664      0.023305         0.091525        0.010359       1
# 3       0.153166      0.041698         0.047402        0.018427       1
# 4       0.124601      0.017902         0.066439        0.007524      10
# 5       0.197663      0.049175         0.053000        0.013806      10
# 6       0.167734      0.058375         0.071264        0.007173     100
# 7       0.361347      0.072630         0.031756        0.003264     100
#
#   param_kernel                          params  split0_test_score  \
# 0          rbf     {'C': 0.1, 'kernel': 'rbf'}           0.777236
# 1       linear  {'C': 0.1, 'kernel': 'linear'}           0.804878
# 2          rbf       {'C': 1, 'kernel': 'rbf'}           0.813008
# 3       linear    {'C': 1, 'kernel': 'linear'}           0.811382
# 4          rbf      {'C': 10, 'kernel': 'rbf'}           0.814634
# 5       linear   {'C': 10, 'kernel': 'linear'}           0.811382
# 6          rbf     {'C': 100, 'kernel': 'rbf'}           0.814634
# 7       linear  {'C': 100, 'kernel': 'linear'}           0.813008
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.775244           0.771987           0.754072           0.780130
# 1           0.802932           0.799674           0.788274           0.796417
# 2           0.820847           0.819218           0.802932           0.807818
# 3           0.789902           0.809446           0.798046           0.807818
# 4           0.814332           0.812704           0.812704           0.811075
# 5           0.789902           0.811075           0.798046           0.809446
# 6           0.807818           0.801303           0.799674           0.812704
# 7           0.806189           0.814332           0.802932           0.812704
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.771734        0.009221                8
# 1         0.798435        0.005841                7
# 2         0.812764        0.006756                2
# 3         0.803319        0.008132                6
# 4         0.813090        0.001287                1
# 5         0.803970        0.008584                5
# 6         0.807227        0.005956                4
# 7         0.809833        0.004460                3

# %%
result[['param_C', 'param_kernel', 'mean_test_score', 'rank_test_score']]
# Out:
#   param_C param_kernel  mean_test_score  rank_test_score
# 0     0.1          rbf         0.771734                8
# 1     0.1       linear         0.798435                7
# 2       1          rbf         0.812764                2
# 3       1       linear         0.803319                6
# 4      10          rbf         0.813090                1
# 5      10       linear         0.803970                5
# 6     100          rbf         0.807227                4
# 7     100       linear         0.809833                3

# %%
grid.best_score_
# Out:
# 0.8130896957178042

# %%
dir(grid)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_refit_for_multimetric',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_format_results',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_required_parameters',
#  '_run_search',
#  '_select_best_index',
#  '_validate_data',
#  '_validate_params',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
#  'decision_function',
#  'error_score',
#  'estimator',
#  'fit',
#  'get_metadata_routing',
#  'get_params',
#  'inverse_transform',
#  'multimetric_',
#  'n_features_in_',
#  'n_jobs',
#  'n_splits_',
#  'param_grid',
#  'pre_dispatch',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'refit',
#  'refit_time_',
#  'return_train_score',
#  'score',
#  'score_samples',
#  'scorer_',
#  'scoring',
#  'set_params',
#  'transform',
#  'verbose']

# %%
grid.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'C': [1, 3, 5, 8, 10, 12],
    'kernel': ['rbf']
}

# Initialize the GridSearchCV object
grid = GridSearchCV(SVC(gamma = 'auto'), param_grid, refit=True, verbose=2, cv  = 5)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ....................................C=1, kernel=rbf; total time=   0.3s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.3s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=3, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=3, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=3, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=3, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=3, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=5, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=5, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=5, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=5, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=5, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=8, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=8, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=8, kernel=rbf; total time=   0.2s
# [CV] END ....................................C=8, kernel=rbf; total time=   0.3s
# [CV] END ....................................C=8, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=12, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=12, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=12, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=12, kernel=rbf; total time=   0.2s
# [CV] END ...................................C=12, kernel=rbf; total time=   0.2s
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 3, 5, 8, 10, 12], 'kernel': ['rbf']},
#              verbose=2)

# %%
result = pd.DataFrame(grid.cv_results_)
result[['param_C', 'param_kernel', 'mean_test_score', 'rank_test_score']]
# Out:
#   param_C param_kernel  mean_test_score  rank_test_score
# 0       1          rbf         0.812764                5
# 1       3          rbf         0.812765                4
# 2       5          rbf         0.814393                1
# 3       8          rbf         0.813415                2
# 4      10          rbf         0.813090                3
# 5      12          rbf         0.812764                6

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'C': [1, 3, 5, 8, 10, 12],
    'kernel': ['rbf']
}

# Initialize the GridSearchCV object
grid = GridSearchCV(SVC(gamma = 'auto', C = '5'), param_grid, refit=True, verbose=2, cv  = 5)
grid.fit(x_train, y_train)

# %% [markdown]
# ### FFT Data Set

# %%
df = pd.read_csv('Dataset/fft_combined_metrics.csv')
df.head()
# Out:
#      Mean_X  Std Dev_X    Energy_X  Entropy_X  Peaks_X    Mean_Y  Std Dev_Y  \
# 0  1.172719   0.953548  228.452251   2.865350       29  1.931631   1.361601
# 1  1.163221   0.958761  227.230673   2.881920       29  1.952115   1.346225
# 2  1.182756   0.936522  227.598408   2.218724       29  1.957486   1.349040
# 3  1.175147   0.940437  226.539145   2.278367       29  2.011669   1.374634
# 4  1.171057   0.945039  226.447322   2.310572       29  2.023791   1.413078
#
#      Energy_Y  Entropy_Y  Peaks_Y  ...  Std Dev_Z    Energy_Z  Entropy_Z  \
# 0  558.515526   3.218825       31  ...   0.658508  130.824569   3.302440
# 1  562.307429   3.220042       31  ...   0.667691  133.851993   3.386925
# 2  565.166173   3.321991       31  ...   0.670604  135.547673   3.013327
# 3  593.642824   3.225947       34  ...   0.684978  138.293642   3.495668
# 4  609.251935   3.003790       32  ...   0.696539  139.649782   3.947268
#
#    Peaks_Z  Mean_Mixed  Std Dev_Mixed  Energy_Mixed  Entropy_Mixed  \
# 0       32    1.443353       2.654877    913.163896       0.613507
# 1       30    1.449463       2.662081    918.761645       0.613295
# 2       32    1.448431       2.671869    923.683803       0.612855
# 3       31    1.498116       2.700763    953.847164       0.611485
# 4       29    1.505199       2.727926    970.720591       0.610666
#
#    Peaks_Mixed  category
# 0           36         1
# 1           36         1
# 2           36         1
# 3           34         1
# 4           36         1
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#             Mean_X    Std Dev_X     Energy_X    Entropy_X      Peaks_X  \
# count  3973.000000  3973.000000  3973.000000  3973.000000  3973.000000
# mean      0.910118     0.815451   182.977277    -1.915309    32.717594
# std       0.414421     0.406002   128.608666     9.784505     2.753609
# min       0.150392     0.107503     3.607243   -37.400630    22.000000
# 25%       0.734849     0.624568    96.453454     1.910015    31.000000
# 50%       0.993760     0.849696   179.532718     2.508717    33.000000
# 75%       1.185268     1.120234   274.306994     2.967466    35.000000
# max       1.685348     1.676827   512.466163     4.393714    43.000000
#
#             Mean_Y    Std Dev_Y     Energy_Y    Entropy_Y      Peaks_Y  ...  \
# count  3973.000000  3973.000000  3973.000000  3973.000000  3973.000000  ...
# mean      1.523480     1.107266   434.556139     2.210277    32.483514  ...
# std       0.710094     0.542681   332.233342     2.145608     2.914879  ...
# min       0.298142     0.222406    15.144836    -9.285003    22.000000  ...
# 25%       1.158567     0.689660   183.132059     2.396423    30.000000  ...
# 50%       1.585905     1.218130   402.699444     3.003114    32.000000  ...
# 75%       1.956400     1.456068   604.935876     3.449377    34.000000  ...
# max       3.081441     2.411332  1301.681677     5.044083    44.000000  ...
#
#          Std Dev_Z     Energy_Z    Entropy_Z      Peaks_Z   Mean_Mixed  \
# count  3973.000000  3973.000000  3973.000000  3973.000000  3973.000000
# mean      0.628477   124.161684   -10.892330    32.492827     1.156918
# std       0.382807    99.387140    28.052992     2.912929     0.523973
# min       0.055354     1.201854  -125.938648    21.000000     0.226559
# 25%       0.402016    53.761310     1.397232    30.000000     0.893994
# 50%       0.569183    94.566925     2.219514    32.000000     1.282872
# 75%       0.936147   206.294905     2.717331    34.000000     1.491859
# max       1.445333   359.903702     4.572684    45.000000     2.123951
#
#        Std Dev_Mixed  Energy_Mixed  Entropy_Mixed  Peaks_Mixed     category
# count    3973.000000   3973.000000    3973.000000  3973.000000  3973.000000
# mean        2.181089    741.566786       0.250422    32.136169     2.997735
# std         1.022665    534.909563       0.769163     2.955755     1.398368
# min         0.409409     22.145086      -2.437729    23.000000     1.000000
# 25%         1.613542    344.293334       0.523529    30.000000     2.000000
# 50%         2.349764    722.647069       0.593080    32.000000     3.000000
# 75%         2.846927   1024.830056       0.645490    34.000000     4.000000
# max         3.900115   1882.861360       0.865078    42.000000     5.000000
#
# [8 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Mean_X           0
# Std Dev_X        0
# Energy_X         0
# Entropy_X        0
# Peaks_X          0
# Mean_Y           0
# Std Dev_Y        0
# Energy_Y         0
# Entropy_Y        0
# Peaks_Y          0
# Mean_Z           0
# Std Dev_Z        0
# Energy_Z         0
# Entropy_Z        0
# Peaks_Z          0
# Mean_Mixed       0
# Std Dev_Mixed    0
# Energy_Mixed     0
# Entropy_Mixed    0
# Peaks_Mixed      0
# category         0
# dtype: int64

# %%
# Separate features and target
x = df.iloc[:, :-1]  # Features
y = df.iloc[:, -1]   # Target

# %%
# Standardize the features
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.3, random_state = 42)

# %%
# Train the Model
classifier_rbf = SVC(kernel = "rbf", random_state = 42)
classifier_rbf.fit(x_train,y_train)
# Out:
# SVC(random_state=42)

# %%
# Predict
y_pred = classifier_rbf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9941275167785235

# %%
k = 10  # number of folds
cv_scores = cross_val_score(classifier_rbf, x, y, cv=k)
cv_scores.mean()
# Out:
# 0.9504632735465742
